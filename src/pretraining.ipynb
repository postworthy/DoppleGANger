# %%
# 🤪 AEI_NET Dataset Creation

# %%
# PRETRAINING COULD TAKE A WHILE BUT ONLY NEEDS TO BE RUN ONE TIME
from preprocess_inswapper import do_inswapper_pretraining
#do_inswapper_pretraining(use_fixed_image=True)
#do_inswapper_pretraining(use_fixed_image=False)
do_inswapper_pretraining(
    data_dirs=[
        "/TrainingData/celeb_turbo/",
        "/TrainingData/sdxl_turbo_faces/",
        "/TrainingData/FromBadges/crop",
        "/TrainingData/img_align_celeba/img_align_celeba_crop/",
        "/TrainingData/lfw_funneled/CROP/",
        "/TrainingData/real_faces_128/",
        "/TrainingData/cartoonset100k_jpg/",
        #"/TrainingData/DigiFace1M/",
        "/TrainingData/bitmojis/",
        "/TrainingData/CineFace1.0/",
        "/TrainingData/face2comics_v2.0.0_by_Sxela/comics/",
        "/TrainingData/face2comics_v2.0.0_by_Sxela/faces/",
        "/TrainingData/vggface2/",
    ],
    output_dir="./data/kitchensink_128/",
    use_fixed_image=False,
    shuffle=True)
# Out:
# 2025-02-08 07:27:11.059076: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-02-08 07:27:11.134934: I tensorflow/core/util/util.cc:169] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-02-08 07:27:11.152203: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# DATASET CREATION COULD TAKE A WHILE BUT ONLY NEEDS TO BE RUN ONE TIME
#from create_dataset import main
#main("./data/pretraining/", "./data/training.tfrecord")
